# %% [markdown]
# <a href="https://colab.research.google.com/github/Annepikson/HypatiaAcademy/blob/master/29_3_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import seaborn as sns
a = np.random.normal(loc=0, scale=3, size=25)

b= np.round(a).astype(int)
c= b.reshape(5,5)
sns.heatmap(c)

for i in range(c.shape[0]):
    for j in range(c.shape[1]):
        plt.annotate(text=str(c[i, j]), xy=(j + 0.5, i + 0.5), ha='center', va='center', color='white')

plt.show()
