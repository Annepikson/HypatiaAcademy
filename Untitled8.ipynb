# %% [markdown]
# <a href="https://colab.research.google.com/github/Annepikson/HypatiaAcademy/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2024-04-09 в 4.46.45 PM.png](data:image/png;base64,...)
