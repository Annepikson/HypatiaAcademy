# %% [markdown]
# <a href="https://colab.research.google.com/github/Annepikson/HypatiaAcademy/blob/master/31_5_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Creating a sample DataFrame
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data)
print(df)
print('------------')
# Converting to a NumPy array
numpy_array = df.to_numpy()

print(numpy_array)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# ------------
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from pylab import *
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

games = pd.read_csv ('https://raw.githubusercontent.com/Annepikson/HypatiaAcademy/master/ml/ratings.csv')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Game Name  101 non-null    object
#  1   Developer  101 non-null    object
#  2   Genre      101 non-null    object
#  3   Rating     101 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.3+ KB

# %%
games
# Out:
#             Game Name           Developer              Genre  Rating
# 0    Candy Crush Saga                King             Puzzle     4.6
# 1      Clash of Clans           Supercell           Strategy     4.5
# 2            Among Us          InnerSloth              Party     4.4
# 3          Pokémon GO             Niantic  Augmented Reality     4.3
# 4         PUBG Mobile       Tencent Games      Battle Royale     4.2
# ..                ...                 ...                ...     ...
# 96     Stardew Valley        ConcernedApe         Simulation     4.7
# 97              Hades    Supergiant Games             Action     4.9
# 98        Plague Inc.    Ndemic Creations           Strategy     4.5
# 99   Alto's Adventure  Noodlecake Studios     Endless Runner     4.7
# 100          The Room     Fireproof Games             Puzzle     4.8
#
# [101 rows x 4 columns]

# %%
games.dropna(axis=1,inplace=True)

# %%
games
# Out:
#             Game Name           Developer              Genre  Rating
# 0    Candy Crush Saga                King             Puzzle     4.6
# 1      Clash of Clans           Supercell           Strategy     4.5
# 2            Among Us          InnerSloth              Party     4.4
# 3          Pokémon GO             Niantic  Augmented Reality     4.3
# 4         PUBG Mobile       Tencent Games      Battle Royale     4.2
# ..                ...                 ...                ...     ...
# 96     Stardew Valley        ConcernedApe         Simulation     4.7
# 97              Hades    Supergiant Games             Action     4.9
# 98        Plague Inc.    Ndemic Creations           Strategy     4.5
# 99   Alto's Adventure  Noodlecake Studios     Endless Runner     4.7
# 100          The Room     Fireproof Games             Puzzle     4.8
#
# [101 rows x 4 columns]

# %%
row_0 = games.iloc[0]
print(row_0)
# Out:
# Game Name    Candy Crush Saga
# Developer                King
# Genre                  Puzzle
# Rating                    4.6
# Name: 0, dtype: object
